# %%
import pandas as pd

df = pd.read_csv('pokemon.csv')
print(df)
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df_xls= pd.read.excel('pokemon.xlsx')
print(df_xlsx.head(3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f148983ebf30> in <module>
# ----> 1 df_xls= pd.read.excel('pokemon.xlsx')
#       2 print(df_xlsx.head(3))
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df= pd.read_csv('pokemon-data.txt')
print(df)
# Out:
#       Bulbasaur
# 0       Ivysaur
# 1      Venusaur
# 2    Charmander
# 3    Charmeleon
# 4     Charizard
# 5      Squirtle
# 6     Wartortle
# 7     Blastoise
# 8      Caterpie
# 9       Metapod
# 10   Butterfree
# 11       Weedle
# 12       Kakuna
# 13     Beedrill
# 14       Pidgey
# 15    Pidgeotto
# 16      Pidgeot
# 17      Rattata
# 18     Raticate
# 19      Spearow
# 20       Fearow
# 21        Ekans
# 22        Arbok
# 23      Pikachu
# 24       Raichu
# 25    Sandshrew
# 26    Sandslash
# 27     Nidoran♀
# 28     Nidorina
# 29    Nidoqueen
# ..          ...
# 771    Silvally
# 772      Minior
# 773      Komala
# 774  Turtonator
# 775  Togedemaru
# 776     Mimikyu
# 777     Bruxish
# 778      Drampa
# 779    Dhelmise
# 780    Jangmo-o
# 781    Hakamo-o
# 782     Kommo-o
# 783   Tapu Koko
# 784   Tapu Lele
# 785   Tapu Bulu
# 786   Tapu Fini
# 787      Cosmog
# 788     Cosmoem
# 789    Solgaleo
# 790      Lunala
# 791    Nihilego
# 792    Buzzwole
# 793   Pheromosa
# ...

# %%
df= pd.read_csv('pokemon-data.txt', deimiter='/')
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-28a00bee6962> in <module>
# ----> 1 df= pd.read_csv('pokemon-data.txt', deimiter='/')
#       2 print(df)
#
# TypeError: parser_f() got an unexpected keyword argument 'deimiter'

# %%
#reading header, column header name

df= pd.read_csv('pokemon.csv')
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read specific col
print(df['Name'])
# Out:
# 0                      Bulbasaur
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 9                       Squirtle
# 10                     Wartortle
# 11                     Blastoise
# 12       BlastoiseMega Blastoise
# 13                      Caterpie
# 14                       Metapod
# 15                    Butterfree
# 16                        Weedle
# 17                        Kakuna
# 18                      Beedrill
# 19         BeedrillMega Beedrill
# 20                        Pidgey
# 21                     Pidgeotto
# 22                       Pidgeot
# 23           PidgeotMega Pidgeot
# 24                       Rattata
# 25                      Raticate
# 26                       Spearow
# 27                        Fearow
# ...

# %%
print(df['Name'][0:7])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# 6                Charizard
# Name: Name, dtype: object

# %%
print(df['Name','Type 1', 'HP']) # single[] returns single cols, to make multiple cols
# I need to make col names as list i.e, [[ ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Type 1', 'HP')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0d915e40131c> in <module>
# ...

# %%
print(df[['Name','Type 1', 'HP']])
# Out:
#                           Name    Type 1   HP
# 0                    Bulbasaur     Grass   45
# 1                      Ivysaur     Grass   60
# 2                     Venusaur     Grass   80
# 3        VenusaurMega Venusaur     Grass   80
# 4                   Charmander      Fire   39
# 5                   Charmeleon      Fire   58
# 6                    Charizard      Fire   78
# 7    CharizardMega Charizard X      Fire   78
# 8    CharizardMega Charizard Y      Fire   78
# 9                     Squirtle     Water   44
# 10                   Wartortle     Water   59
# 11                   Blastoise     Water   79
# 12     BlastoiseMega Blastoise     Water   79
# 13                    Caterpie       Bug   45
# 14                     Metapod       Bug   50
# 15                  Butterfree       Bug   60
# 16                      Weedle       Bug   40
# 17                      Kakuna       Bug   45
# 18                    Beedrill       Bug   65
# ...

# %%
print(df[['Name','Type 1', 'HP']][0:5])
# Out:
#                     Name Type 1  HP
# 0              Bulbasaur  Grass  45
# 1                Ivysaur  Grass  60
# 2               Venusaur  Grass  80
# 3  VenusaurMega Venusaur  Grass  80
# 4             Charmander   Fire  39

# %%
#to print index

print(df.iloc[1]) #it returns the info of first row
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
print(df.iloc[1:5])
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# to get specific location, to display just Charmander's name
# 4th row and 2nd col, col stats from 0th index. Tachnically, secod col's index is 1
print(df.iloc[4,1])
# Out:
# Charmander

# %%
#iterate through each row

for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# ...

# %%
for index, row in df.iterrows():
    print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
# find specific daata in db
# thisreturns the data of type 1 which is equal to fire

df.loc[df['Type 1']== "Fire"]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df.loc[df['Type 1']== "Grass"]
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 0      1                Bulbasaur  Grass    Poison    318   45      49
# 1      2                  Ivysaur  Grass    Poison    405   60      62
# 2      3                 Venusaur  Grass    Poison    525   80      82
# 3      3    VenusaurMega Venusaur  Grass    Poison    625   80     100
# 48    43                   Oddish  Grass    Poison    320   45      50
# 49    44                    Gloom  Grass    Poison    395   60      65
# 50    45                Vileplume  Grass    Poison    490   75      80
# 75    69               Bellsprout  Grass    Poison    300   50      75
# 76    70               Weepinbell  Grass    Poison    390   65      90
# 77    71               Victreebel  Grass    Poison    490   80     105
# 110  102                Exeggcute  Grass   Psychic    325   60      40
# 111  103                Exeggutor  Grass   Psychic    520   95      95
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# Pokemon name sorting
df.sort_values('Name')
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 510  460                  Abomasnow     Grass       Ice    494   90      92
# 511  460    AbomasnowMega Abomasnow     Grass       Ice    594   90     132
# 68    63                       Abra   Psychic       NaN    310   25      20
# 392  359                      Absol      Dark       NaN    465   65     130
# 393  359            AbsolMega Absol      Dark       NaN    565   65     150
# 678  617                   Accelgor       Bug       NaN    495   80      70
# 750  681       AegislashBlade Forme     Steel     Ghost    520   60     150
# 751  681      AegislashShield Forme     Steel     Ghost    520   60      50
# 153  142                 Aerodactyl      Rock    Flying    515   80     105
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 332  306                     Aggron     Steel      Rock    530   70     110
# ...

# %%
#Im sorting values of Type 1. Types are bug, fire water etc, ascending would be bug, if ascending=false 
#then water pokemon will display first
df.sort_values(['Type 1'], ascending= True)
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 600  540                 Sewaddle    Bug     Grass    310   45      53
# 136  127                   Pinsir    Bug       NaN    500   65     125
# 457  412                    Burmy    Bug       NaN    224   40      29
# 132  123                  Scyther    Bug    Flying    500   70     110
# 656  595                   Joltik    Bug  Electric    319   50      47
# 657  596               Galvantula    Bug  Electric    472   70      77
# 288  265                  Wurmple    Bug       NaN    195   45      45
# 289  266                  Silcoon    Bug       NaN    205   50      35
# 677  616                  Shelmet    Bug       NaN    305   50      40
# 232  214  HeracrossMega Heracross    Bug  Fighting    600   80     185
# 290  267                Beautifly    Bug    Flying    395   60      70
# 693  632                   Durant    Bug     Steel    484   58     109
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending= True) 
# this displays type and HP in ascending order. First bug pokemon will be sorted and up there HP will be sorted in asc
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 316  292               Shedinja    Bug     Ghost    236    1      90       45
# 230  213                Shuckle    Bug      Rock    505   20      10      230
# 462  415                 Combee    Bug    Flying    244   30      30       42
# 603  543               Venipede    Bug    Poison    260   30      45       59
# 314  290                Nincada    Bug    Ground    266   31      45       90
# 51    46                  Paras    Bug     Grass    285   35      70       55
# 446  401              Kricketot    Bug       NaN    194   37      25       41
# 732  664             Scatterbug    Bug       NaN    200   38      35       40
# 16    13                 Weedle    Bug    Poison    195   40      35       30
# 179  165                 Ledyba    Bug    Flying    265   40      20       30
# 181  167               Spinarak    Bug    Poison    250   40      60       40
# ...

# %%
#in last ex, both Type and HP were in ascendig order, if I want type to be asc n HP to des

df.sort_values(['Type 1', 'HP'], ascending= [1,0])
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# 734  666                 Vivillon    Bug    Flying    411  80      52
# 447  402               Kricketune    Bug       NaN    384  77      85
# 220  205               Forretress    Bug     Steel    465  75      90
# 602  542                 Leavanny    Bug     Grass    500  75     103
# 717  649                 Genesect    Bug     Steel    600  71     120
# 54    49                 Venomoth    Bug    Poison    450  70      65
# 132  123                  Scyther    Bug    Flying    500  70     110
# ...

# %%
df.sort_values(['Type 1', 'HP','Speed'], ascending= [1,0,0])
# Type 1 has many bugs, acc to that HP was in descending order. 
# now, bugs, HP in desc order. Check with value HP as 80,in 5 vals of 80, speed is in dec order
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 678  617                 Accelgor    Bug       NaN    495  80      70
# 734  666                 Vivillon    Bug    Flying    411  80      52
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 447  402               Kricketune    Bug       NaN    384  77      85
# 602  542                 Leavanny    Bug     Grass    500  75     103
# 220  205               Forretress    Bug     Steel    465  75      90
# 717  649                 Genesect    Bug     Steel    600  71     120
# 657  596               Galvantula    Bug  Electric    472  70      77
# 132  123                  Scyther    Bug    Flying    500  70     110
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Total1']= df['HP']+df['Attack']+df['Defense']+df['Speed']
df['Total1']
# Out:
# 0      188
# 1      245
# 2      325
# 3      383
# 4      199
# 5      260
# 6      340
# 7      419
# 8      360
# 9      200
# 10     260
# 11     340
# 12     380
# 13     155
# 14     155
# 15     225
# 16     155
# 17     155
# 18     270
# 19     400
# 20     181
# 21     249
# 22     339
# 23     364
# 24     193
# 25     293
# 26     200
# 27     320
# 28     194
# 29     294
#       ...
# 770    285
# 771    363
# 772    283
# 773    300
# 774    170
# 775    256
# 776    340
# 777    303
# 778    199
# 779    327
# 780    236
# 781    236
# 782    236
# 783    236
# 784    361
# 785    361
# 786    361
# 787    361
# 788    237
# 789    424
# 790    160
# 791    358
# 792    451
# 793    451
# 794    424
# 795    350
# 796    430
# 797    320
# 798    380
# 799    380
# Name: Total1, Length: 800, dtype: int64

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total1
# 0       65       65     45           1      False     188
# 1       80       80     60           1      False     245
# 2      100      100     80           1      False     325
# 3      122      120     80           1      False     383
# 4       60       50     65           1      False     199

# %%
df.drop(columns=['Total1']) #if sometimes it doesn't delete then df= df.drop(columns=['Total1'])
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
#other way to create new col and to manipulate the column function
# iloc[:], here : is for all rows, and columns from 4th to 9th
#if I just mention sum() then it returns NaN
#if Axis is 1 then it is horizontal, vertical sum is axis=1, then again Total1 is NaN
#total- last 10th col is not inclusive

df['Total1']= df.iloc[:, 4:10].sum(axis=1)

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total1
# 0       65       65     45           1      False     591
# 1       80       80     60           1      False     750
# 2      100      100     80           1      False     970
# 3      122      120     80           1      False    1170
# 4       60       50     65           1      False     553

# %%
#if I want to make changes the position of total in table/ re-order the columns
# col0= #, col 4 is total, when Im saying col[0:4] 4th col total will be excluded. Here 0 to 4 has str and 
#12th col is Generation, as I don't need it Im specifying as 4:12 from total to speed
#col[-1]is last col Total 1
#I have just gven all as + + +, as it is combi of str and numbers, I cant concatenate with str n numbers
# Hence, I got error like, can only concatenate list (not "str") to list
#so I should provide extra [] with cols[-1] as it has only 1 value, so that I can consider it as list


cols=list(df.columns) #cols has all the column names which is enclosed in a list


df=df[cols[0:4] + [cols[-1]]+ cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Speed  Generation  Total1  Total  \
# 0  1              Bulbasaur  Grass  Poison     45           1     591    318
# 1  2                Ivysaur  Grass  Poison     60           1     750    405
# 2  3               Venusaur  Grass  Poison     80           1     970    525
# 3  3  VenusaurMega Venusaur  Grass  Poison     80           1    1170    625
# 4  4             Charmander   Fire     NaN     65           1     553    309
#
#    HP  Attack  Defense  Sp. Atk  Sp. Def
# 0  45      49       49       65       65
# 1  60      62       63       80       80
# 2  80      82       83      100      100
# 3  80     100      123      122      120
# 4  39      52       43       60       50

# %%
# the manipulation with data is not actually saved in csv file. 
# we're creating a new csv file and copy all data in df
#just df.to_csv('modifiedPokemon.csv') works but it shows index col which is mostly wrong, so to exclude this we've 
# pass arg like index=false
# to save in excel, df.to_excel(


df.to_csv('modifiedPokemon.csv', index=False)

# %% [markdown]
# # Filtering

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                     Name Type 1    Type 2  Speed  Generation  Total1  \
# 0      1                Bulbasaur  Grass    Poison     45           1     591
# 1      2                  Ivysaur  Grass    Poison     60           1     750
# 2      3                 Venusaur  Grass    Poison     80           1     970
# 3      3    VenusaurMega Venusaur  Grass    Poison     80           1    1170
# 48    43                   Oddish  Grass    Poison     30           1     610
# 49    44                    Gloom  Grass    Poison     40           1     750
# 50    45                Vileplume  Grass    Poison     50           1     930
# 75    69               Bellsprout  Grass    Poison     40           1     560
# 76    70               Weepinbell  Grass    Poison     55           1     725
# 77    71               Victreebel  Grass    Poison     70           1     910
# 110  102                Exeggcute  Grass   Psychic     40           1     610
# ...

# %%
# Multiple conditions
#df.loc[df['Type 1'] == 'Grass' & df['Type 2'] == 'Poison'], this throws error, cannot compare a dtyped [object] array with a scalar of type [bool]
#check with seperators, brackets btw 2 conditions. (df[] )& (df[])
# In pandas we cant use AND, OR, we need to use notiations 

df.loc[(df['Type 1'] == 'Grass')& (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Total1  \
# 0      1              Bulbasaur  Grass  Poison     45           1     591
# 1      2                Ivysaur  Grass  Poison     60           1     750
# 2      3               Venusaur  Grass  Poison     80           1     970
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1    1170
# 48    43                 Oddish  Grass  Poison     30           1     610
# 49    44                  Gloom  Grass  Poison     40           1     750
# 50    45              Vileplume  Grass  Poison     50           1     930
# 75    69             Bellsprout  Grass  Poison     40           1     560
# 76    70             Weepinbell  Grass  Poison     55           1     725
# 77    71             Victreebel  Grass  Poison     70           1     910
# 344  315                Roselia  Grass  Poison     65           3     735
# 451  406                  Budew  Grass  Poison     55           4     505
# ...

# %%
newdf= df.loc[(df['Type 1'] == 'Grass')& (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
newdf

# real data is still in df, we have filtered and saved in new df
# but the index are so different
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Total1  \
# 2      3               Venusaur  Grass  Poison     80           1     970
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1    1170
# 50    45              Vileplume  Grass  Poison     50           1     930
# 77    71             Victreebel  Grass  Poison     70           1     910
# 652  591              Amoonguss  Grass  Poison     30           5     898
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 2      525   80      82       83      100      100
# 3      625   80     100      123      122      120
# 50     490   75      80       85      110       90
# 77     490   80     105       65      100       70
# 652    464  114      85       70       85       80

# %%
# to reset index

newdf= newdf.reset_index()
newdf
# Out:
#    index    #                   Name Type 1  Type 2  Speed  Generation  \
# 0      2    3               Venusaur  Grass  Poison     80           1
# 1      3    3  VenusaurMega Venusaur  Grass  Poison     80           1
# 2     50   45              Vileplume  Grass  Poison     50           1
# 3     77   71             Victreebel  Grass  Poison     70           1
# 4    652  591              Amoonguss  Grass  Poison     30           5
#
#    Total1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 0     970    525   80      82       83      100      100
# 1    1170    625   80     100      123      122      120
# 2     930    490   75      80       85      110       90
# 3     910    490   80     105       65      100       70
# 4     898    464  114      85       70       85       80

# %%
# but ld index value still there in a separate col as index, lets remove the col
# did not get output
newdf= newdf.reset_index(drop=True)
newdf
# Out:
#    index    #                   Name Type 1  Type 2  Speed  Generation  \
# 0      2    3               Venusaur  Grass  Poison     80           1
# 1      3    3  VenusaurMega Venusaur  Grass  Poison     80           1
# 2     50   45              Vileplume  Grass  Poison     50           1
# 3     77   71             Victreebel  Grass  Poison     70           1
# 4    652  591              Amoonguss  Grass  Poison     30           5
#
#    Total1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 0     970    525   80      82       83      100      100
# 1    1170    625   80     100      123      122      120
# 2     930    490   75      80       85      110       90
# 3     910    490   80     105       65      100       70
# 4     898    464  114      85       70       85       80

# %%
# lets filter out with the name contained Mega
#first lets see how many names has mega
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Speed  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison     80           1
# 7      6  CharizardMega Charizard X      Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire    Flying    100           1
# 12     9    BlastoiseMega Blastoise     Water       NaN     78           1
# 19    15      BeedrillMega Beedrill       Bug    Poison    145           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying    121           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN    150           1
# 87    80        SlowbroMega Slowbro     Water   Psychic     30           1
# 102   94          GengarMega Gengar     Ghost    Poison    130           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    100           1
# 137  127          PinsirMega Pinsir       Bug    Flying    105           1
# ...

# %%
#this excludes the names with mega 
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                   Name    Type 1  Type 2  Speed  Generation  Total1  \
# 0      1              Bulbasaur     Grass  Poison     45           1     591
# 1      2                Ivysaur     Grass  Poison     60           1     750
# 2      3               Venusaur     Grass  Poison     80           1     970
# 4      4             Charmander      Fire     NaN     65           1     553
# 5      5             Charmeleon      Fire     NaN     80           1     730
# 6      6              Charizard      Fire  Flying    100           1     968
# 9      7               Squirtle     Water     NaN     43           1     585
# 10     8              Wartortle     Water     NaN     58           1     752
# 11     9              Blastoise     Water     NaN     78           1     982
# 13    10               Caterpie       Bug     NaN     45           1     345
# 14    11                Metapod       Bug     NaN     30           1     380
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass')]
# Out:
#        #                       Name Type 1    Type 2  Speed  Generation  \
# 0      1                  Bulbasaur  Grass    Poison     45           1
# 1      2                    Ivysaur  Grass    Poison     60           1
# 2      3                   Venusaur  Grass    Poison     80           1
# 3      3      VenusaurMega Venusaur  Grass    Poison     80           1
# 4      4                 Charmander   Fire       NaN     65           1
# 5      5                 Charmeleon   Fire       NaN     80           1
# 6      6                  Charizard   Fire    Flying    100           1
# 7      6  CharizardMega Charizard X   Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y   Fire    Flying    100           1
# 42    37                     Vulpix   Fire       NaN     65           1
# 43    38                  Ninetales   Fire       NaN    100           1
# 48    43                     Oddish  Grass    Poison     30           1
# ...

# %%
df.loc[df['Type 1'].str.contains('fire|grass')]#here none are caught as I have not specific about col name capitalisation
# to ignore the capitalisation, we need to use regular expression
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Speed, Generation, Total1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def]
# Index: []

# %%
import re # inporting regular expression
#capilatisation ignore case

df.loc[df['Type 1'].str.contains('fire|grass', flags = re.I, regex=True)]
# Out:
#        #                       Name Type 1    Type 2  Speed  Generation  \
# 0      1                  Bulbasaur  Grass    Poison     45           1
# 1      2                    Ivysaur  Grass    Poison     60           1
# 2      3                   Venusaur  Grass    Poison     80           1
# 3      3      VenusaurMega Venusaur  Grass    Poison     80           1
# 4      4                 Charmander   Fire       NaN     65           1
# 5      5                 Charmeleon   Fire       NaN     80           1
# 6      6                  Charizard   Fire    Flying    100           1
# 7      6  CharizardMega Charizard X   Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y   Fire    Flying    100           1
# 42    37                     Vulpix   Fire       NaN     65           1
# 43    38                  Ninetales   Fire       NaN    100           1
# 48    43                     Oddish  Grass    Poison     30           1
# ...

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('fire|Grass', regex=True)]
# Out:
#        #                     Name Type 1    Type 2  Speed  Generation  Total1  \
# 0      1                Bulbasaur  Grass    Poison     45           1     591
# 1      2                  Ivysaur  Grass    Poison     60           1     750
# 2      3                 Venusaur  Grass    Poison     80           1     970
# 3      3    VenusaurMega Venusaur  Grass    Poison     80           1    1170
# 48    43                   Oddish  Grass    Poison     30           1     610
# 49    44                    Gloom  Grass    Poison     40           1     750
# 50    45                Vileplume  Grass    Poison     50           1     930
# 75    69               Bellsprout  Grass    Poison     40           1     560
# 76    70               Weepinbell  Grass    Poison     55           1     725
# 77    71               Victreebel  Grass    Poison     70           1     910
# 110  102                Exeggcute  Grass   Psychic     40           1     610
# ...

# %%
# if I want pokmon's names starts with pi 
#use reguar expression, pi[a-z]* this inclused all the names which has pi in the names.

df.loc[df['Name'].str.contains('pi[a-z]*', flags= re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Speed  Generation  \
# 13    10                 Caterpie       Bug       NaN     45           1
# 20    16                   Pidgey    Normal    Flying     56           1
# 21    17                Pidgeotto    Normal    Flying     71           1
# 22    18                  Pidgeot    Normal    Flying    101           1
# 23    18      PidgeotMega Pidgeot    Normal    Flying    121           1
# 30    25                  Pikachu  Electric       NaN     90           1
# 42    37                   Vulpix      Fire       NaN     65           1
# 76    70               Weepinbell     Grass    Poison     55           1
# 84    78                 Rapidash      Fire       NaN    105           1
# 136  127                   Pinsir       Bug       NaN     85           1
# 137  127        PinsirMega Pinsir       Bug    Flying    105           1
# 181  167                 Spinarak       Bug    Poison     30           2
# ...

# %%
# ^pi[a-z]* starts with pi and * includes all 

df.loc[df['Name'].str.contains('^pi[a-z]*', flags= re.I, regex=True)]
# Out:
#        #                 Name    Type 1  Type 2 Speed Generation Total1 Total  \
# 20    16               Pidgey    Normal  Flying    56          1    446   251
# 21    17            Pidgeotto    Normal  Flying    71          1    627   349
# 22    18              Pidgeot    Normal  Flying   101          1    857   479
# 23    18  PidgeotMega Pidgeot    Normal  Flying   121          1   1037   579
# 30    25              Pikachu  Electric     NaN    90          1    550   320
# 136  127               Pinsir       Bug     NaN    85          1    915   500
# 137  127    PinsirMega Pinsir       Bug  Flying   105          1   1095   600
# 186  172                Pichu  Electric     NaN    60          2    350   205
# 219  204               Pineco       Bug     NaN    15          2    565   290
# 239  221            Piloswine       Ice  Ground    50          2    850   450
# 438  393               Piplup     Water     NaN    40          4    588   314
# ...

# %% [markdown]
# # Conditional Changes

# %%
df = pd.read_csv('pokemon.csv')
print(df)
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
# if I didnt like fire name and replace it with flamer
# df['Type 1'] == "Fire", 'Type 1'  -> take all the values of Type 1 whose value is Fire.  now df.loc has all the 
#values iwth fire, now replace it with name flamer


# df.loc[df['Type 1'] == "Fire", Type 1]= "Flamer", in the same col Type 1
#if df[type1]'s value is fire,then change it to flamer
df.loc[df['Type 1'] == "Fire", 'Type 1']= "Flamer"
df
# Out:
#         #                     Name    Type 1  Type 2 Total    HP Attack  \
# 0       1                Bulbasaur     Grass  Poison   318    45     49
# 1       2                  Ivysaur     Grass  Poison   405    60     62
# 2       3                 Venusaur     Grass  Poison   525    80     82
# 3       3    VenusaurMega Venusaur     Grass  Poison   625    80    100
# 4    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 5    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 6    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 7    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 8    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 9       7                 Squirtle     Water     NaN   314    44     48
# 10      8                Wartortle     Water     NaN   405    59     63
# 11      9                Blastoise     Water     NaN   530    79     83
# ...

# %%
#this makes all the values as fire(right of th bracket) where the value of Type 1 is flamer
#df.loc[df['Type 1'] == "Fire", 'Type 1']= "Flamer"
#df
##df1= df.loc[df['Type 1'] == "Flamer"]= "Fire"
#df1

# %%
#df= pd.read_csv(Pokemon.csv)

# %%
df.loc[df['Type 1'] == "Flamer", 'Type 1']= "Fire"
df
# Out:
#         #                     Name    Type 1  Type 2 Total    HP Attack  \
# 0       1                Bulbasaur     Grass  Poison   318    45     49
# 1       2                  Ivysaur     Grass  Poison   405    60     62
# 2       3                 Venusaur     Grass  Poison   525    80     82
# 3       3    VenusaurMega Venusaur     Grass  Poison   625    80    100
# 4    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 5    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 6    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 7    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 8    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 9       7                 Squirtle     Water     NaN   314    44     48
# 10      8                Wartortle     Water     NaN   405    59     63
# 11      9                Blastoise     Water     NaN   530    79     83
# ...

# %%
#to make all type of fire pokemon's legendary col is true
# so here we have creating a new col called legendary and passing values as true

# asI ran the code wrong, all the fire type values have been replaced.
df.loc[df['Type 1'] == "Fire", 'Legendary']= True
df
# Out:
#         #                     Name    Type 1  Type 2 Total    HP Attack  \
# 0       1                Bulbasaur     Grass  Poison   318    45     49
# 1       2                  Ivysaur     Grass  Poison   405    60     62
# 2       3                 Venusaur     Grass  Poison   525    80     82
# 3       3    VenusaurMega Venusaur     Grass  Poison   625    80    100
# 4    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 5    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 6    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 7    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 8    Fire                     Fire      Fire    Fire  Fire  Fire   Fire
# 9       7                 Squirtle     Water     NaN   314    44     48
# 10      8                Wartortle     Water     NaN   405    59     63
# 11      9                Blastoise     Water     NaN   530    79     83
# ...

# %%
df.iloc[df['Total'] > 500, ['Generation' , 'Legendary']] = 'Test'

# as I have manipulated the data, it is getting the error as total now has str value as well.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-f92857457f66> in <module>
# ----> 1 df.iloc[df['Total'] > 500, ['Generation' , 'Legendary']] = 'Test'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
df2 = pd.read_csv('modifiedPokemon.csv')
df2
# Out:
#        #                       Name    Type 1  Type 2  Speed  Generation  \
# 0      1                  Bulbasaur     Grass  Poison     45           1
# 1      2                    Ivysaur     Grass  Poison     60           1
# 2      3                   Venusaur     Grass  Poison     80           1
# 3      3      VenusaurMega Venusaur     Grass  Poison     80           1
# 4      4                 Charmander      Fire     NaN     65           1
# 5      5                 Charmeleon      Fire     NaN     80           1
# 6      6                  Charizard      Fire  Flying    100           1
# 7      6  CharizardMega Charizard X      Fire  Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire  Flying    100           1
# 9      7                   Squirtle     Water     NaN     43           1
# 10     8                  Wartortle     Water     NaN     58           1
# 11     9                  Blastoise     Water     NaN     78           1
# ...

# %%
df2['Legendary']= 10
df2
# Out:
#        #                       Name    Type 1  Type 2  Speed  Generation  \
# 0      1                  Bulbasaur     Grass  Poison     45           1
# 1      2                    Ivysaur     Grass  Poison     60           1
# 2      3                   Venusaur     Grass  Poison     80           1
# 3      3      VenusaurMega Venusaur     Grass  Poison     80           1
# 4      4                 Charmander      Fire     NaN     65           1
# 5      5                 Charmeleon      Fire     NaN     80           1
# 6      6                  Charizard      Fire  Flying    100           1
# 7      6  CharizardMega Charizard X      Fire  Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire  Flying    100           1
# 9      7                   Squirtle     Water     NaN     43           1
# 10     8                  Wartortle     Water     NaN     58           1
# 11     9                  Blastoise     Water     NaN     78           1
# ...

# %%
# if I need to modify multiple columns with the single value, then pass multiple values with a list

import re
df2.loc[df['Total'] > 500, ['Generation' , 'Legendary']] = "test"
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-639eb084cb88> in <module>
#       2
#       3 import re
# ----> 4 df2.loc[df['Total'] > 500, ['Generation' , 'Legendary']] = "test"
#       5 df2
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ...

# %%
#If I need to manipulate data of different columns with different values then pass the new values inlist too

df2.loc[df['Total'] > 500, ['Generation' , 'Legendary']] = ['Test1', 'Test 2']
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-f2b526b92061> in <module>
#       1 #If I need to manipulate data of different columns with different values then pass the new values inlist too
#       2
# ----> 3 df2.loc[df['Total'] > 500, ['Generation' , 'Legendary']] = ['Test1', 'Test 2']
#       4 df2
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
# ...

# %% [markdown]
# # Agrregate Statistics (Groupby)

# %%
df3= pd.read_csv('modifiedPokemon.csv')
df3
# Out:
#        #                       Name    Type 1  Type 2  Speed  Generation  \
# 0      1                  Bulbasaur     Grass  Poison     45           1
# 1      2                    Ivysaur     Grass  Poison     60           1
# 2      3                   Venusaur     Grass  Poison     80           1
# 3      3      VenusaurMega Venusaur     Grass  Poison     80           1
# 4      4                 Charmander      Fire     NaN     65           1
# 5      5                 Charmeleon      Fire     NaN     80           1
# 6      6                  Charizard      Fire  Flying    100           1
# 7      6  CharizardMega Charizard X      Fire  Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire  Flying    100           1
# 9      7                   Squirtle     Water     NaN     43           1
# 10     8                  Wartortle     Water     NaN     58           1
# 11     9                  Blastoise     Water     NaN     78           1
# ...

# %%
df3.groupby(['Type 1']).mean()
# Out:
#                    #       Speed  Generation       Total1       Total  \
# Type 1
# Bug       334.492754   61.681159    3.217391   696.173913  378.927536
# Dark      461.354839   76.161290    4.032258   815.322581  445.741935
# Dragon    474.375000   83.031250    3.875000  1018.031250  550.531250
# Electric  363.500000   84.500000    3.272727   802.318182  443.409091
# Fairy     449.529412   48.588235    4.117647   777.764706  413.176471
# Fighting  363.851852   66.074074    3.370370   766.814815  416.444444
# Fire      327.403846   74.442308    3.211538   841.711538  458.076923
# Flying    677.750000  102.500000    5.500000   867.500000  485.000000
# Ghost     486.500000   64.343750    4.187500   814.781250  439.562500
# Grass     344.871429   61.928571    3.357143   780.357143  421.142857
# Ground    356.281250   63.906250    3.156250   811.093750  437.500000
# Ice       423.541667   63.458333    3.541667   803.458333  433.458333
# ...

# %%
df3.groupby(['Type 1']).mean().sort_values("Defense") #fairy pokemon has low defense
# Out:
#                    #       Speed  Generation       Total1       Total  \
# Type 1
# Normal    319.173469   71.551020    3.051020   731.816327  401.683673
# Fairy     449.529412   48.588235    4.117647   777.764706  413.176471
# Fighting  363.851852   66.074074    3.370370   766.814815  416.444444
# Flying    677.750000  102.500000    5.500000   867.500000  485.000000
# Electric  363.500000   84.500000    3.272727   802.318182  443.409091
# Psychic   380.807018   81.491228    3.385965   870.403509  475.947368
# Fire      327.403846   74.442308    3.211538   841.711538  458.076923
# Poison    251.785714   63.571429    2.535714   734.714286  399.142857
# Dark      461.354839   76.161290    4.032258   815.322581  445.741935
# Bug       334.492754   61.681159    3.217391   696.173913  378.927536
# Grass     344.871429   61.928571    3.357143   780.357143  421.142857
# Ice       423.541667   63.458333    3.541667   803.458333  433.458333
# ...

# %%
df3.groupby(['Type 1']).mean().sort_values("Defense", ascending= False)

#steel pokemon has highest defense
# Out:
#                    #       Speed  Generation       Total1       Total  \
# Type 1
# Steel     442.851852   55.259259    3.851852   920.148148  487.703704
# Rock      392.727273   55.909091    3.454545   851.590909  453.750000
# Dragon    474.375000   83.031250    3.875000  1018.031250  550.531250
# Ground    356.281250   63.906250    3.156250   811.093750  437.500000
# Ghost     486.500000   64.343750    4.187500   814.781250  439.562500
# Water     303.089286   65.964286    2.857143   794.946429  430.455357
# Ice       423.541667   63.458333    3.541667   803.458333  433.458333
# Grass     344.871429   61.928571    3.357143   780.357143  421.142857
# Bug       334.492754   61.681159    3.217391   696.173913  378.927536
# Dark      461.354839   76.161290    4.032258   815.322581  445.741935
# Poison    251.785714   63.571429    2.535714   734.714286  399.142857
# Fire      327.403846   74.442308    3.211538   841.711538  458.076923
# ...

# %%
df3.groupby(['Type 1']).mean().sort_values("Attack", ascending= False)

#dragon has highest attack
# Out:
#                    #       Speed  Generation       Total1       Total  \
# Type 1
# Dragon    474.375000   83.031250    3.875000  1018.031250  550.531250
# Fighting  363.851852   66.074074    3.370370   766.814815  416.444444
# Ground    356.281250   63.906250    3.156250   811.093750  437.500000
# Rock      392.727273   55.909091    3.454545   851.590909  453.750000
# Steel     442.851852   55.259259    3.851852   920.148148  487.703704
# Dark      461.354839   76.161290    4.032258   815.322581  445.741935
# Fire      327.403846   74.442308    3.211538   841.711538  458.076923
# Flying    677.750000  102.500000    5.500000   867.500000  485.000000
# Poison    251.785714   63.571429    2.535714   734.714286  399.142857
# Water     303.089286   65.964286    2.857143   794.946429  430.455357
# Ghost     486.500000   64.343750    4.187500   814.781250  439.562500
# Normal    319.173469   71.551020    3.051020   731.816327  401.683673
# ...

# %%
df3.groupby(['Type 1']).sum()
# Out:
#               #  Speed  Generation  Total1  Total    HP  Attack  Defense  \
# Type 1
# Bug       23080   4256         222   48036  26146  3925    4897     4880
# Dark      14302   2361         125   25275  13818  2071    2740     2177
# Dragon    15180   2657         124   32577  17617  2666    3588     2764
# Electric  15994   3718         144   35302  19510  2631    3040     2917
# Fairy      7642    826          70   13222   7024  1260    1046     1117
# Fighting   9824   1784          91   20704  11244  1886    2613     1780
# Fire      17025   3871         167   43769  23820  3635    4408     3524
# Flying     2711    410          22    3470   1940   283     315      265
# Ghost     15568   2059         134   26073  14066  2062    2361     2598
# Grass     24141   4335         235   54625  29480  4709    5125     4956
# Ground    11401   2045         101   25955  14000  2361    3064     2715
# Ice       10165   1523          85   19283  10403  1728    1746     1714
# ...

# %%
df3.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Speed  Generation  Total1  Total   HP  Attack  \
# Type 1
# Bug        69    69      52     69          69      69     69   69      69
# Dark       31    31      21     31          31      31     31   31      31
# Dragon     32    32      21     32          32      32     32   32      32
# Electric   44    44      17     44          44      44     44   44      44
# Fairy      17    17       2     17          17      17     17   17      17
# Fighting   27    27       7     27          27      27     27   27      27
# Fire       52    52      24     52          52      52     52   52      52
# Flying      4     4       2      4           4       4      4    4       4
# Ghost      32    32      22     32          32      32     32   32      32
# Grass      70    70      37     70          70      70     70   70      70
# Ground     32    32      19     32          32      32     32   32      32
# ...

# %%
# to clean data
# if all the values are repetative, counts of most are repetative

# first all a new col called count
df3['MyCount']= 1
df3
#df3.groupby(['Type 1']).[count]
# Out:
#        #                       Name    Type 1  Type 2  Speed  Generation  \
# 0      1                  Bulbasaur     Grass  Poison     45           1
# 1      2                    Ivysaur     Grass  Poison     60           1
# 2      3                   Venusaur     Grass  Poison     80           1
# 3      3      VenusaurMega Venusaur     Grass  Poison     80           1
# 4      4                 Charmander      Fire     NaN     65           1
# 5      5                 Charmeleon      Fire     NaN     80           1
# 6      6                  Charizard      Fire  Flying    100           1
# 7      6  CharizardMega Charizard X      Fire  Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire  Flying    100           1
# 9      7                   Squirtle     Water     NaN     43           1
# 10     8                  Wartortle     Water     NaN     58           1
# 11     9                  Blastoise     Water     NaN     78           1
# ...

# %%
df3.drop(['Count'], axis= 1)
df3
# Out:
#        #                       Name    Type 1  Type 2  Speed  Generation  \
# 0      1                  Bulbasaur     Grass  Poison     45           1
# 1      2                    Ivysaur     Grass  Poison     60           1
# 2      3                   Venusaur     Grass  Poison     80           1
# 3      3      VenusaurMega Venusaur     Grass  Poison     80           1
# 4      4                 Charmander      Fire     NaN     65           1
# 5      5                 Charmeleon      Fire     NaN     80           1
# 6      6                  Charizard      Fire  Flying    100           1
# 7      6  CharizardMega Charizard X      Fire  Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire  Flying    100           1
# 9      7                   Squirtle     Water     NaN     43           1
# 10     8                  Wartortle     Water     NaN     58           1
# 11     9                  Blastoise     Water     NaN     78           1
# ...

# %%
#new col called Count was made by mistake please ignore

# to make it easy . How many types of pokemons are there. 

df3['MyCount']= 1
df3.groupby(['Type 1']).count()['MyCount']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: MyCount, dtype: int64

# %%
# multiple parameters

df3.groupby(['Type 1', 'Type 2']).count()['MyCount']
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
# ...

# %% [markdown]
# # Working with large Dataset

# %%
# large data set will have 20Gbs, pandas lets read in chunk

for df3 in pd.read_csv('modifiedpokemon.csv', chunksize= 5): #1000000 rows at a time
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#         #                     Name    Type 1  Type 2 Total    HP Attack  \
# 0       1                Bulbasaur     Grass  Poison   318    45     49
# 1       2                  Ivysaur     Grass  Poison   405    60     62
# 2       3                 Venusaur     Grass  Poison   525    80     82
# 3       3    VenusaurMega Venusaur     Grass  Poison   625    80    100
# 4    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 5    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 6    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 7    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 8    Fire                     Fire    Flamer    Fire  Fire  Fire   Fire
# 9       7                 Squirtle     Water     NaN   314    44     48
# 10      8                Wartortle     Water     NaN   405    59     63
# 11      9                Blastoise     Water     NaN   530    79     83
# ...

# %%
new_df= pd.
